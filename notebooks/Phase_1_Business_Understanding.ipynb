# %% [markdown]
# # Phase 1: Business Understanding
#
# **CRISP-DM Phase Description:**
# This phase focuses on understanding the project objectives and requirements from a business perspective, then converting this knowledge into a data mining problem definition and a preliminary plan designed to achieve the objectives.
#
# ---

# %% [markdown]
# ### Task 1: Determine Business Objectives
#
# The first objective of the data analyst is to thoroughly understand, from a business perspective, what the customer really wants to accomplish. This involves:
#
# - **Background:** Identify the organisational context and the business area the project relates to.
# - **Business Objectives:** Clearly state the primary question or problem the business wants to solve.
# - **Business Success Criteria:** Define the measurable criteria that determine whether the project's outcome is considered a success from the business's point of view (e.g., "reduce customer churn by 15%", "improve prediction accuracy to 90%").
#
# **Instructions:** In the cells below, define your business objectives, background context, and success criteria as Python variables (strings or dictionaries). This ensures your business logic is documented directly in the notebook's code state.

# %%
# TODO: Define business objectives here.
# Example:
# business_objectives = {
#     "background": "Describe the organisational context and business area...",
#     "primary_objective": "What is the main business question or problem?",
#     "success_criteria": [
#         "Criterion 1: e.g., Reduce X by Y%",
#         "Criterion 2: e.g., Achieve Z accuracy"
#     ]
# }

business_objectives = {
    "background": """This project focuses on traffic volume forecasting in an urban transportation setting. Traffic congestion causes delays, increased fuel consumption, and environmental impact. Using historical data such as time, weather, and holidays, this project aims to predict traffic patterns and support better traffic management and planning.""",

    "primary_objective": """Develop a predictive model that can accurately estimate traffic volume based on historical data, including time, weather conditions, and holiday information.""",

    "success_criteria": [
        "Build a working predictive model for traffic_volume",
        "Achieve an R² score of at least 0.75 on the test dataset",
        "Achieve a lower RMSE than a simple baseline model",
        "Ensure the model generalizes well to unseen data",
        "Identify key factors affecting traffic volume such as time of day and weather"
    ]
}

# %%
# Display the defined objectives in a readable format
import textwrap

for key, value in business_objectives.items():
    print(f">> {key.upper().replace('_', ' ')}:")
    if isinstance(value, list):
        for item in value:
            wrapped_item = textwrap.fill(item, width=80, subsequent_indent="     ")
            print(f"   - {wrapped_item}")
    else:
        wrapped_value = textwrap.fill(value, width=90, subsequent_indent="   ")
        print(f"   {wrapped_value}")
    print()
# Out:
# >> BACKGROUND:
#    This project focuses on traffic volume forecasting in an urban transportation setting.
#    Traffic congestion causes delays, increased fuel consumption, and environmental impact.
#    Using historical data such as time, weather, and holidays, this project aims to predict
#    traffic patterns and support better traffic management and planning.
#
# >> BUSINESS OBJECTIVE:
#    Develop a predictive model that can accurately estimate traffic volume based on historical
#    data, including time, weather conditions, and holiday information.
#
# >> SUCCESS CRITERIA:
#    - Build a working predictive model for traffic_volume
#    - Achieve an R² score of at least 0.75 on the test dataset
#    - Achieve a lower RMSE than a simple baseline model
#    - Ensure the model generalizes well to unseen data
#    - Identify key factors affecting traffic volume such as time of day and weather

# %% [markdown]
# ---
# ### Task 2: Assess Situation
#
# This task involves a more detailed fact-finding about all of the resources, constraints, assumptions, and other factors that should be considered in determining the data analysis goal and project plan. Key areas to assess:
#
# - **Resources Inventory:** Personnel, data sources, computing resources, and software available.
# - **Requirements, Assumptions, and Constraints:** Project schedule, legal/ethical considerations, data access limitations, and budget.
# - **Risks and Contingencies:** Identify potential risks (e.g., data unavailability, quality issues, privacy concerns) and how to mitigate them.
# - **Terminology Glossary:** Define key domain-specific terms relevant to the project.
# - **Costs and Benefits:** A cost-benefit analysis of the project.
#
# **Instructions:** Document your situation assessment as a structured dictionary or set of variables.

# %%
# TODO: Assess the current situation here.
# Document resources, requirements, assumptions, constraints, and risks.

situation_assessment = {
    "resources": {
        "personnel": [],      # e.g., ["Data Scientist", "Domain Expert"]
        "data_sources": [],   # e.g., ["Internal DB", "Public API", "CSV files"]
        "computing": "",      # e.g., "Local machine / Cloud platform"
        "software": []        # e.g., ["Python 3.x", "scikit-learn", "pandas"]
    },
    "requirements": [],       # e.g., ["Must comply with GDPR", "Deadline: DD/MM/YYYY"]
    "assumptions": [],        # e.g., ["Data is representative of the population"]
    "constraints": [],        # e.g., ["Limited to 10,000 records", "No budget for cloud"]
    "risks_and_contingencies": [
        # {"risk": "Description", "probability": "Low/Medium/High", "mitigation": "Plan"}
    ],
    "terminology": {
        # "Term": "Definition"
    },
    "cost_benefit": ""
}

situation_assessment = {
    "resources": {
        "personnel": ["Data Science Student", "Course Instructor (Supervisor)"],
        "data_sources": ["Metro Interstate Traffic Volume Dataset (CSV)"],
        "computing": "Local machine (VS Code with Anaconda environment)",
        "software": [
            "Python 3.x",
            "pandas",
            "numpy",
            "matplotlib",
            "seaborn",
            "scikit-learn",
            "Jupyter Notebook",
            "VS Code",
            "Git/GitHub"
        ]
    },

    "requirements": [
        "Use publicly available dataset",
        "Ensure ethical use of data (no privacy issues)",
        "All results must be reproducible using the provided code",
        "Model should provide meaningful and interpretable predictions"
    ],

    "assumptions": [
        "The dataset is representative of real traffic patterns",
        "Traffic volume is influenced by time, weather, and holidays",
        "Historical data can be used to predict future traffic",
        "The dataset has sufficient quality for analysis"
    ],

    "constraints": [
        "The dataset is limited to a specific location and time period",
        "No real-time or live traffic data is available",
        "Feature set is limited to the variables provided in the dataset",
        "Model performance depends on the quality and completeness of the dataset"
    ],

    "risks_and_contingencies": [
        {
            "risk": "Missing or inconsistent data",
            "probability": "Medium",
            "mitigation": "Handle missing values during preprocessing"
        },
        {
            "risk": "Model performs poorly",
            "probability": "Medium",
            "mitigation": "Try different models and tune parameters"
        },
        {
            "risk": "Incorrect data interpretation",
            "probability": "Low",
            "mitigation": "Perform proper data exploration and validation"
        }
    ],

    "terminology": {
        "Traffic Volume": "Number of vehicles passing a location in a given time period",
        "Regression": "A method used to predict continuous numerical values",
        "Feature": "An input variable used in the model",
        "Target Variable": "The variable to be predicted (traffic_volume)"
    },

    "cost_benefit": "The project has low cost since it uses publicly available data and a local machine. The benefits are high, as accurate traffic prediction can improve traffic management, reduce congestion, and support better urban planning."
}

# %%
# Display situation assessment
import json
print(json.dumps(situation_assessment, indent=2))
# Out:
# {
#   "resources": {
#     "personnel": [
#       "Data Science Student",
#       "Course Instructor (Supervisor)"
#     ],
#     "data_sources": [
#       "Metro Interstate Traffic Volume Dataset (CSV)"
#     ],
#     "computing": "Local machine (VS Code with Anaconda environment)",
#     "software": [
#       "Python 3.x",
#       "pandas",
#       "numpy",
#       "matplotlib",
#       "seaborn",
#       "scikit-learn",
#       "Jupyter Notebook",
#       "VS Code",
#       "Git/GitHub"
#     ]
#   },
#   "requirements": [
#     "Use publicly available dataset",
#     "Ensure ethical use of data (no privacy issues)",
#     "All results must be reproducible using the provided code",
#     "Model should provide meaningful and interpretable predictions"
#   ],
#   "assumptions": [
#     "The dataset is representative of real traffic patterns",
#     "Traffic volume is influenced by time, weather, and holidays",
#     "Historical data can be used to predict future traffic",
# ...

# %%
# Optional: Add any further notes or elaboration on the situation assessment

# %% [markdown]
# ---
# ### Task 3: Determine Data Mining Goals
#
# A business goal states objectives in business terminology. A data mining goal states project objectives in technical terms. This task converts the business objectives identified in Task 1 into specific, measurable data mining goals:
#
# - **Data Mining Problem Type:** Classify the problem (e.g., classification, regression, clustering, anomaly detection, association rule mining, etc.).
# - **Data Mining Goals:** State the technical objectives clearly (e.g., "Build a classification model to predict [target variable] with an F1-score ≥ 0.85").
# - **Data Mining Success Criteria:** Define the technical metrics that will be used to evaluate the model's performance (e.g., accuracy, precision, recall, RMSE, silhouette score).
#
# **Instructions:** Map your business objectives to concrete data mining goals.

# %%
# TODO: Define data mining goals here.

data_mining_goals = {
    "problem_type": "",  # e.g., "Binary Classification", "Regression", "Clustering"
    "target_variable": "",  # e.g., "customer_churn", "house_price"
    "technical_goals": [
        # "Goal 1: e.g., Build a model to predict [target] with accuracy > 85%"
    ],
    "success_metrics": [
        # "Metric 1: e.g., F1-Score >= 0.80",
        # "Metric 2: e.g., AUC-ROC >= 0.85"
    ]
}

data_mining_goals = {
    "problem_type": "Regression",
    
    "target_variable": "traffic_volume",
    
    "technical_goals": [
        "Build a regression model to predict traffic_volume using historical features such as date/time, weather conditions, and holiday information",
        "Prepare the dataset by cleaning missing values, encoding categorical variables, and extracting useful time-based features from date_time",
        "Compare multiple regression models to identify the best-performing approach",
        "Analyze feature importance or model influence to understand which factors most affect traffic volume",
        "Generate predictions that are accurate enough to support traffic pattern analysis and forecasting"
    ],
    
    "success_metrics": [
        "R² score >= 0.75 on the test set",
        "RMSE lower than a simple baseline model",
        "MAE kept as low as possible for practical prediction accuracy",
        "Model shows consistent performance on unseen test data"
    ]
}

# %%
import textwrap

print("Business to Data Mining Goal Mapping\n")

print("Business Objective:")
print(textwrap.fill(business_objectives['primary_objective'], width=90))

print("\nProblem Type:")
print(data_mining_goals['problem_type'])

print("\nTarget Variable:")
print(data_mining_goals['target_variable'])

print("\nTechnical Goals:")
for goal in data_mining_goals['technical_goals']:
    print(textwrap.fill(f"- {goal}", width=90))

print("\nSuccess Metrics:")
for metric in data_mining_goals['success_metrics']:
    print(textwrap.fill(f"- {metric}", width=90))
# Out:
# Business to Data Mining Goal Mapping
#
# Business Objective:
# Develop a predictive model that can accurately estimate traffic volume based on historical
# data, including time, weather conditions, and holiday information.
#
# Problem Type:
# Regression
#
# Target Variable:
# traffic_volume
#
# Technical Goals:
# - Build a regression model to predict traffic_volume using historical features such as
# date/time, weather conditions, and holiday information
# - Prepare the dataset by cleaning missing values, encoding categorical variables, and
# extracting useful time-based features from date_time
# - Compare multiple regression models to identify the best-performing approach
# - Analyze feature importance or model influence to understand which factors most affect
# traffic volume
# - Generate predictions that are accurate enough to support traffic pattern analysis and
# forecasting
#
# Success Metrics:
# - R² score >= 0.75 on the test set
# - RMSE lower than a simple baseline model
# ...

# %% [markdown]
# ---
# ### Task 4: Produce Project Plan
#
# Describe the intended plan for achieving the data mining goals and thereby achieving the business goals. The plan should specify:
#
# - **Tools and Techniques:** The data mining tools (libraries, frameworks) and modelling techniques you plan to use.
# - **Project Plan / Timeline:** A step-by-step plan with estimated durations for each remaining CRISP-DM phase.
# - **Dependencies:** Any dependencies between tasks or on external factors.
# - **Initial Assessment of Tools and Techniques:** A brief justification for why the chosen tools and techniques are appropriate.
#
# **Instructions:** Outline your full project plan as a structured data object below.

# %%
# TODO: Produce your project plan here.

project_plan = {
    "tools": [
        # e.g., "pandas", "scikit-learn", "matplotlib", "seaborn", "XGBoost"
    ],
    "techniques": [
        # e.g., "Logistic Regression", "Random Forest", "K-Means Clustering"
    ],
    "timeline": [
        # {"phase": "Data Understanding",  "duration": "Week 1-2", "status": "Not Started"},
        # {"phase": "Data Preparation",    "duration": "Week 2-4", "status": "Not Started"},
        # {"phase": "Modelling",           "duration": "Week 4-5", "status": "Not Started"},
        # {"phase": "Evaluation",          "duration": "Week 5-6", "status": "Not Started"},
        # {"phase": "Deployment",          "duration": "Week 6",   "status": "Not Started"}
    ],
    "dependencies": [
        # "Data access must be granted before Data Understanding can begin."
    ],
    "tool_justification": ""
}

project_plan = {
    "tools": [
        "Python 3.x",
        "pandas",
        "numpy",
        "matplotlib",
        "seaborn",
        "scikit-learn",
        "Jupyter Notebook",
        "VS Code",
        "Git/GitHub"
    ],

    "techniques": [
        "Exploratory Data Analysis (EDA)",
        "Data Cleaning and Preprocessing",
        "Feature Engineering",
        "Categorical Encoding",
        "Train-Test Split",
        "Regression Modeling",
        "Model Evaluation"
    ],

    "timeline": [
        {"phase": "Business Understanding", "duration": "Completed", "status": "Done"},
        {"phase": "Data Understanding", "duration": "1 phase", "status": "Planned"},
        {"phase": "Data Preparation", "duration": "1 phase", "status": "Planned"},
        {"phase": "Modeling", "duration": "1 phase", "status": "Planned"},
        {"phase": "Evaluation", "duration": "1 phase", "status": "Planned"},
        {"phase": "Deployment", "duration": "1 phase", "status": "Planned"}
    ],

    "dependencies": [
        "The dataset must be successfully loaded before analysis can begin",
        "Data understanding must be completed before data preparation",
        "Data preparation must be completed before modeling",
        "Modeling must be completed before evaluation",
        "Evaluation results will guide the final deployment summary"
    ],

    "tool_justification": "These tools and techniques are appropriate because they support the full workflow of a traffic forecasting project, from data exploration and preprocessing to regression modeling and evaluation. Python and its libraries provide reliable support for handling structured tabular data, visualizing traffic patterns, preparing features, building predictive models, and evaluating performance in a reproducible way."
}

# %%
import textwrap

print("Project Plan\n")

print("Tools:")
for tool in project_plan["tools"]:
    print(f"- {tool}")

print("\nTechniques:")
for tech in project_plan["techniques"]:
    print(f"- {tech}")

print("\nTimeline:")
for phase in project_plan['timeline']:
    print(f"[ {phase['phase']:<25} ] | {phase['duration']:<10} | {phase['status']}")

print("\nDependencies:")
for dep in project_plan["dependencies"]:
    print(textwrap.fill(f"- {dep}", width=90))

print("\nTool Justification:")
print(textwrap.fill(project_plan["tool_justification"], width=90))
# Out:
# Project Plan
#
# Tools:
# - Python 3.x
# - pandas
# - numpy
# - matplotlib
# - seaborn
# - scikit-learn
# - Jupyter Notebook
# - VS Code
# - Git/GitHub
#
# Techniques:
# - Exploratory Data Analysis (EDA)
# - Data Cleaning and Preprocessing
# - Feature Engineering
# - Categorical Encoding
# - Train-Test Split
# - Regression Modeling
# - Model Evaluation
#
# Timeline:
# [ Business Understanding    ] | Completed  | Done
# [ Data Understanding        ] | 1 phase    | Planned
# [ Data Preparation          ] | 1 phase    | Planned
# [ Modeling                  ] | 1 phase    | Planned
# [ Evaluation                ] | 1 phase    | Planned
# [ Deployment                ] | 1 phase    | Planned
#
# Dependencies:
# - The dataset must be successfully loaded before analysis can begin
# - Data understanding must be completed before data preparation
# - Data preparation must be completed before modeling
# - Modeling must be completed before evaluation
# ...

# %%
import textwrap

print("Phase 1 Summary\n")

print("Primary Objective:")
print(textwrap.fill(business_objectives["primary_objective"], width=90))

print("\nProblem Type:")
print(data_mining_goals["problem_type"])

print("\nTarget Variable:")
print(data_mining_goals["target_variable"])

print("\nTools:")
for tool in project_plan["tools"]:
    print(f"- {tool}")

print("\nTechniques:")
for tech in project_plan["techniques"]:
    print(f"- {tech}")
# Out:
# Phase 1 Summary
#
# Primary Objective:
# Develop a predictive model that can accurately estimate traffic volume based on historical
# data, including time, weather conditions, and holiday information.
#
# Problem Type:
# Regression
#
# Target Variable:
# traffic_volume
#
# Tools:
# - Python 3.x
# - pandas
# - numpy
# - matplotlib
# - seaborn
# - scikit-learn
# - Jupyter Notebook
# - VS Code
# - Git/GitHub
#
# Techniques:
# - Exploratory Data Analysis (EDA)
# - Data Cleaning and Preprocessing
# - Feature Engineering
# - Categorical Encoding
# - Train-Test Split
# - Regression Modeling
# - Model Evaluation
