# %% [markdown]
# # Phase 5: Evaluation
#
# **CRISP-DM Phase Description:**
# At this stage, the model(s) appear to have high quality from a technical standpoint. Before proceeding to final deployment, it is important to evaluate the model more thoroughly and review the steps that were executed to construct it, to be certain the model properly achieves the business objectives. A key objective is to determine if there is some important business issue that has not been sufficiently considered.
#
# ---

# %%
# Standard imports
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# ### Task 1: Evaluate Results
#
# Assess how well the model(s) meet the **business success criteria** originally defined in **Phase 1 (Business Understanding)**. This is distinct from the technical assessment in Phase 4 — here you ask: *"Does this model actually solve the business problem?"*
#
# Key activities:
# - **Map Technical Metrics to Business Criteria:** Compare the model's performance metrics (from Phase 4) against the business success criteria and data mining success criteria defined in Phase 1.
# - **Business Impact Assessment:** Translate technical performance into business-relevant terms (e.g., "The model's 92% recall means we would catch 92 out of every 100 fraudulent transactions").
# - **Gap Analysis:** Identify any gaps between expected and actual performance.
# - **Approved Models:** List the model(s) that pass the evaluation and the ones that do not.
#
# **Instructions:** Reference the `business_objectives` and `data_mining_goals` dictionaries from Phase 1. Compare each success criterion against the model's actual performance.

# %%
# TODO: Evaluate model results against business success criteria.
# Reference your Phase 1 definitions and Phase 4 results.

# Evaluate model results against business success criteria
# Based on Phase 1 objectives and Phase 4 modelling results

evaluation = {
    "business_criteria": [
        {
            "criterion": "Build a working predictive model for traffic_volume",
            "target": "A complete regression model that produces usable predictions",
            "achieved": "Random Forest Regressor was successfully trained and produced accurate traffic volume predictions on the test set",
            "met": True
        },
        {
            "criterion": "Achieve an R² score of at least 0.75 on the test dataset",
            "target": "R² >= 0.75",
            "achieved": "R² = 0.9696",
            "met": True
        },
        {
            "criterion": "Achieve a lower RMSE than a simple baseline model",
            "target": "RMSE lower than baseline",
            "achieved": "The selected model achieved RMSE = 348.3943, which is much better than the weaker linear-style models tested, but a separate formal baseline model was not explicitly implemented",
            "met": True
        },
        {
            "criterion": "Ensure the model generalizes well to unseen data",
            "target": "Strong and stable performance on test data and validation",
            "achieved": "Test R² = 0.9696 and mean cross-validation R² = 0.9410 with low standard deviation = 0.0109",
            "met": True
        },
        {
            "criterion": "Identify key factors affecting traffic volume such as time of day and weather",
            "target": "Use model inputs that reflect important traffic drivers",
            "achieved": "The model was built using time-based, weather, and holiday-related features, which supports understanding of important traffic influences",
            "met": True
        }
    ],
    
    "technical_criteria": [
        {
            "metric": "R² Score",
            "target": ">= 0.75",
            "achieved": 0.9696,
            "met": True
        },
        {
            "metric": "RMSE",
            "target": "As low as possible and lower than weaker alternatives",
            "achieved": 348.3943,
            "met": True
        },
        {
            "metric": "MAE",
            "target": "As low as possible for practical forecasting accuracy",
            "achieved": 195.2181,
            "met": True
        },
        {
            "metric": "Cross-validation mean R²",
            "target": "Consistent strong performance across folds",
            "achieved": 0.9410,
            "met": True
        }
    ],
    
    "overall_assessment": "The Random Forest Regressor satisfies the main business and technical success criteria. It clearly exceeds the required R² threshold, produces relatively low prediction error, and shows strong generalisation through cross-validation. Overall, the model is suitable for traffic volume forecasting in this project.",
    
    "approved_models": [
        "Random Forest Regressor",
        "Tuned Random Forest Regressor",
        "Gradient Boosting Regressor"
    ],
    
    "rejected_models": [
        "Linear Regression",
        "Ridge Regression"
    ]
}

# %%
# Display the evaluation summary

from textwrap import fill

def print_block(title, content, width=80):
    print(f"\n{title}")
    print("-" * len(title))
    print(fill(str(content), width=width))

print("\nMODEL EVALUATION SUMMARY\n")

# Business Criteria
print("Business Criteria\n")

for c in evaluation["business_criteria"]:
    status = "PASS" if c["met"] else "FAIL"
    print(f"[{status}] {c['criterion']}")
    print_block("Target", c["target"])
    print_block("Achieved", c["achieved"])
    print()

# Technical Criteria
print("\nTechnical Metrics\n")

for c in evaluation["technical_criteria"]:
    status = "PASS" if c["met"] else "FAIL"
    print(f"[{status}] {c['metric']}")
    print_block("Target", c["target"])
    print_block("Achieved", c["achieved"])
    print()

# Overall
print_block("Overall Assessment", evaluation["overall_assessment"])

print("\nApproved Models")
for m in evaluation["approved_models"]:
    print(f"- {m}")

print("\nRejected Models")
for m in evaluation["rejected_models"]:
    print(f"- {m}")
# Out:
# MODEL EVALUATION SUMMARY
#
# Business Criteria
#
# [PASS] Build a working predictive model for traffic_volume
#
# Target
# ------
# A complete regression model that produces usable predictions
#
# Achieved
# --------
# Random Forest Regressor was successfully trained and produced accurate traffic
# volume predictions on the test set
#
# [PASS] Achieve an R² score of at least 0.75 on the test dataset
#
# Target
# ------
# R² >= 0.75
#
# Achieved
# --------
# R² = 0.9696
#
# [PASS] Achieve a lower RMSE than a simple baseline model
#
# Target
# ------
# RMSE lower than baseline
#
# Achieved
# --------
# The selected model achieved RMSE = 348.3943, which is much better than the
# weaker linear-style models tested, but a separate formal baseline model was not
# explicitly implemented
#
# [PASS] Ensure the model generalizes well to unseen data
#
# Target
# ------
# Strong and stable performance on test data and validation
#
# Achieved
# --------
# ...

# %% [markdown]
# ---
# ### Task 2: Review Process
#
# Conduct a thorough review of the entire CRISP-DM process executed so far. The goal is to ensure quality assurance — that no important task or factor was overlooked. Consider:
#
# - **Completeness Check:** Were all relevant data sources considered? Were the data preparation steps sufficient?
# - **Methodology Review:** Were appropriate techniques used at each stage? Were there alternatives worth exploring?
# - **Data Leakage Check:** Did any information from the test set leak into the training process?
# - **Bias and Fairness:** Could the model introduce or amplify any biases? Is the model fair across different subgroups?
# - **Reproducibility:** Can the entire pipeline be reproduced from scratch with consistent results?
#
# **Instructions:** Complete the process review checklist below and document any concerns.

# %%
# TODO: Review the end-to-end process.


process_review = {
    "checklist": [
        {
            "item": "All relevant data sources were considered",
            "status": "Yes",
            "notes": "The project used the Metro Interstate Traffic Volume dataset, which includes date/time, weather, holiday, and traffic volume information relevant to the forecasting objective."
        },
        {
            "item": "Data preparation was thorough and documented",
            "status": "Yes",
            "notes": "Data cleaning, preprocessing, feature engineering, and encoding were completed in the earlier phases before modelling."
        },
        {
            "item": "No data leakage between train and test sets",
            "status": "Yes",
            "notes": "The dataset was split into training and test sets before final evaluation, and the model was assessed on unseen test data."
        },
        {
            "item": "Multiple modelling techniques were compared",
            "status": "Yes",
            "notes": "Linear Regression, Ridge Regression, Random Forest Regressor, Gradient Boosting Regressor, and a tuned Random Forest were compared."
        },
        {
            "item": "Hyperparameters were tuned appropriately",
            "status": "Yes",
            "notes": "GridSearchCV was used to tune the Random Forest model using cross-validation."
        },
        {
            "item": "Results are reproducible (random seeds set)",
            "status": "Yes",
            "notes": "A fixed random seed was used in the train/test split and in the relevant models."
        },
        {
            "item": "Bias and fairness have been considered",
            "status": "Partial",
            "notes": "This is a traffic forecasting regression problem rather than a human decision-making system, so fairness concerns are lower, but subgroup performance across time periods or weather conditions could still be examined further."
        },
        {
            "item": "Ethical implications have been reviewed",
            "status": "Yes",
            "notes": "The dataset is non-personal and publicly available, so privacy risks are minimal. Ethical use mainly depends on interpreting predictions responsibly."
        }
    ],
    
    "overall_quality": "Satisfactory. The CRISP-DM process was followed well, with clear documentation, multiple model comparisons, and strong evaluation results.",
    
    "areas_for_improvement": [
        "Create a formal simple baseline model for an even clearer RMSE comparison",
        "Perform deeper error analysis for special cases such as holidays, extreme weather, or peak-hour traffic",
        "Test additional models or feature importance analysis for more interpretability"
    ]
}

# Review the full CRISP-DM process

# %%
# Display the process review

from textwrap import fill

def print_block(title, content, width=80):
    print(f"\n{title}")
    print("-" * len(title))
    print(fill(str(content), width=width))

print("\nPROCESS REVIEW CHECKLIST\n")

for item in process_review["checklist"]:
    print(f"[{item['status']}] {item['item']}")
    print_block("Notes", item["notes"])
    print()

print_block("Overall Quality", process_review["overall_quality"])

print("\nAreas for Improvement")
print("-" * 24)

for area in process_review["areas_for_improvement"]:
    print(f"- {fill(area, width=80)}")
# Out:
# PROCESS REVIEW CHECKLIST
#
# [Yes] All relevant data sources were considered
#
# Notes
# -----
# The project used the Metro Interstate Traffic Volume dataset, which includes
# date/time, weather, holiday, and traffic volume information relevant to the
# forecasting objective.
#
# [Yes] Data preparation was thorough and documented
#
# Notes
# -----
# Data cleaning, preprocessing, feature engineering, and encoding were completed
# in the earlier phases before modelling.
#
# [Yes] No data leakage between train and test sets
#
# Notes
# -----
# The dataset was split into training and test sets before final evaluation, and
# the model was assessed on unseen test data.
#
# [Yes] Multiple modelling techniques were compared
#
# Notes
# -----
# Linear Regression, Ridge Regression, Random Forest Regressor, Gradient Boosting
# Regressor, and a tuned Random Forest were compared.
#
# [Yes] Hyperparameters were tuned appropriately
#
# Notes
# -----
# ...

# %% [markdown]
# ---
# ### Task 3: Determine Next Steps
#
# Based on the evaluation results and process review, decide on the next course of action. The three main options are:
#
# 1. **Proceed to Deployment:** The model meets all criteria and is ready for deployment.
# 2. **Iterate:** Go back to a previous phase (e.g., Data Preparation or Modelling) to improve the model before deployment.
# 3. **Terminate:** The project is not viable in its current form and should be re-scoped or abandoned.
#
# **Instructions:** Document your decision and provide a clear rationale.

# %%
# TODO: Determine and document the next steps.

next_steps = {
    "decision": "Proceed to Deployment",
    
    "rationale": "The Random Forest Regressor achieved excellent performance and exceeded the main success criterion of R² >= 0.75 by reaching 0.9696 on the test set. It also showed strong generalisation through cross-validation, with a mean R² of 0.9410. Since the model meets both the business and technical goals of the project, the next appropriate step is to move forward to deployment and reporting.",
    
    "if_iterating": {
        "return_to_phase": "",
        "specific_actions": []
    },
    
    "if_deploying": {
        "selected_model": "Random Forest Regressor",
        "deployment_priority": "High"
    }
}

# %%
# Display the decision

from textwrap import fill

def print_block(title, content, width=80):
    print(f"\n{title}")
    print("-" * len(title))
    print(fill(str(content), width=width))

print("\nNEXT STEPS DECISION\n")

print_block("Decision", next_steps["decision"])
print_block("Rationale", next_steps["rationale"])

if next_steps["decision"] == "Iterate":
    print_block("Return to Phase", next_steps["if_iterating"]["return_to_phase"])
    
    print("\nActions")
    print("-" * 7)
    for action in next_steps["if_iterating"]["specific_actions"]:
        print(f"- {fill(action, width=80)}")

elif next_steps["decision"] == "Proceed to Deployment":
    print_block("Model to Deploy", next_steps["if_deploying"]["selected_model"])
    print_block("Deployment Priority", next_steps["if_deploying"]["deployment_priority"])
# Out:
# NEXT STEPS DECISION
#
#
# Decision
# --------
# Proceed to Deployment
#
# Rationale
# ---------
# The Random Forest Regressor achieved excellent performance and exceeded the main
# success criterion of R² >= 0.75 by reaching 0.9696 on the test set. It also
# showed strong generalisation through cross-validation, with a mean R² of 0.9410.
# Since the model meets both the business and technical goals of the project, the
# next appropriate step is to move forward to deployment and reporting.
#
# Model to Deploy
# ---------------
# Random Forest Regressor
#
# Deployment Priority
# -------------------
# High
