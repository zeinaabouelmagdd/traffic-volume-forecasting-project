# %% [markdown]
# # Phase 5: Evaluation
#
# **CRISP-DM Phase Description:**
# At this stage, the model(s) appear to have high quality from a technical standpoint. Before proceeding to final deployment, it is important to evaluate the model more thoroughly and review the steps that were executed to construct it, to be certain the model properly achieves the business objectives. A key objective is to determine if there is some important business issue that has not been sufficiently considered.
#
# ---

# %%
# Standard imports
import pandas as pd
import numpy as np
from textwrap import fill

# %% [markdown]
# ---
# ### Task 1: Evaluate Results
#
# Assess how well the model(s) meet the **business success criteria** originally defined in **Phase 1 (Business Understanding)**. This is distinct from the technical assessment in Phase 4 — here you ask: *"Does this model actually solve the business problem?"*
#
# Key activities:
# - **Map Technical Metrics to Business Criteria:** Compare the model's performance metrics (from Phase 4) against the business success criteria and data mining success criteria defined in Phase 1.
# - **Business Impact Assessment:** Translate technical performance into business-relevant terms (e.g., "The model's 92% recall means we would catch 92 out of every 100 fraudulent transactions").
# - **Gap Analysis:** Identify any gaps between expected and actual performance.
# - **Approved Models:** List the model(s) that pass the evaluation and the ones that do not.
#
# **Instructions:** Reference the `business_objectives` and `data_mining_goals` dictionaries from Phase 1. Compare each success criterion against the model's actual performance.

# %%
# Task 1: Evaluate results against business and technical success criteria

evaluation = {
    "business_criteria": [
        {
            "criterion": "Build a working model to predict traffic volume",
            "target": "A complete regression model that can generate reliable traffic volume predictions",
            "achieved": "Achieved. Multiple regression models were trained and compared, and the Tuned Random Forest Regressor was selected as the final model.",
            "met": True
        },
        {
            "criterion": "Achieve strong predictive performance for practical forecasting use",
            "target": "Model should explain most of the variation in traffic volume and generalise well to unseen data",
            "achieved": "Achieved. The Tuned Random Forest Regressor achieved a test R² of 0.966, meaning it explains about 96.6% of the variation in traffic volume on unseen data.",
            "met": True
        },
        {
            "criterion": "Improve traffic forecasting compared with simpler baseline models",
            "target": "Final model should outperform simpler linear models and other alternatives",
            "achieved": "Achieved. The tuned Random Forest outperformed Linear Regression, Ridge Regression, and Gradient Boosting on the test set, making it the strongest overall model.",
            "met": True
        },
        {
            "criterion": "Produce results useful for future traffic planning and decision-making",
            "target": "Predictions should be accurate enough to support traffic monitoring and planning",
            "achieved": "Largely achieved. The model shows very high predictive accuracy, so it would be useful for estimating expected traffic volume patterns, although real deployment would still require monitoring over time.",
            "met": True
        }
    ],
    
    "technical_criteria": [
        {
            "metric": "Best final model selected through comparison",
            "target": "Choose the strongest model based on evaluation metrics",
            "achieved": "Achieved. The Tuned Random Forest Regressor had the best overall performance among all tested models.",
            "met": True
        },
        {
            "metric": "Test R² score",
            "target": "R² >= 0.75",
            "achieved": "Achieved. Test R² = 0.965982, which is far above the minimum target.",
            "met": True
        },
        {
            "metric": "Cross-validation performance",
            "target": "Consistently strong validation performance",
            "achieved": "Achieved. Best cross-validation score from tuning was approximately 0.9569, showing strong and stable generalisation.",
            "met": True
        },
        {
            "metric": "Generalisation gap",
            "target": "No major drop between training and test performance",
            "achieved": "Achieved. The model remained strong on the test set, suggesting good generalisation, although tree-based models still require awareness of possible overfitting.",
            "met": True
        }
    ],
    
    "model_comparison_summary": [
        "Tuned Random Forest Regressor was the best-performing model overall.",
        "Standard Random Forest Regressor was also very strong, but slightly weaker than the tuned version.",
        "Gradient Boosting Regressor performed well, but below both Random Forest models.",
        "Linear Regression and Ridge Regression performed much worse, indicating that the traffic patterns are too complex for simple linear models."
    ],
    
    "business_impact": [
        "The final model can estimate traffic volume with high accuracy, making it useful for traffic planning, congestion monitoring, and resource allocation.",
        "A model explaining about 96.6% of traffic variation suggests that important traffic patterns were captured successfully.",
        "The model could help support operational decisions such as identifying peak traffic periods and anticipating demand patterns.",
        "However, this project remains an academic implementation, so real-world deployment would still require ongoing monitoring and retraining when traffic behaviour changes."
    ],
    
    "limitations": [
        "The model was trained on historical data, so future traffic behaviour may change over time.",
        "Performance was evaluated on the available dataset only, not on a live production environment.",
        "Although results are excellent, interpretability is lower for Random Forest compared with simpler linear models."
    ],
    
    "overall_conclusion": "The final evaluation shows that the project was successful. The Tuned Random Forest Regressor clearly met and exceeded the main technical and business success criteria, making it a suitable final model for the traffic volume forecasting task."
}

# %%
# Display evaluation results clearly

def print_block(title, content, width=100):
    print(f"\n{title}")
    print("-" * len(title))
    print(fill(str(content), width=width))

print("PHASE 5 - TASK 1: EVALUATE RESULTS")
print("=" * 38)

print("\nBUSINESS SUCCESS CRITERIA")
print("=" * 25)

for item in evaluation["business_criteria"]:
    status = "PASS" if item["met"] else "FAIL"
    print(f"\n[{status}] {item['criterion']}")
    print_block("Target", item["target"])
    print_block("Achieved", item["achieved"])

print("\nTECHNICAL SUCCESS CRITERIA")
print("=" * 26)

for item in evaluation["technical_criteria"]:
    status = "PASS" if item["met"] else "FAIL"
    print(f"\n[{status}] {item['metric']}")
    print_block("Target", item["target"])
    print_block("Achieved", item["achieved"])

print("\nMODEL COMPARISON SUMMARY")
print("=" * 24)
for point in evaluation["model_comparison_summary"]:
    print(f"- {fill(point, width=100)}")

print("\nBUSINESS IMPACT")
print("=" * 15)
for point in evaluation["business_impact"]:
    print(f"- {fill(point, width=100)}")

print("\nLIMITATIONS")
print("=" * 11)
for point in evaluation["limitations"]:
    print(f"- {fill(point, width=100)}")

print_block("Overall Conclusion", evaluation["overall_conclusion"])
# Out:
# PHASE 5 - TASK 1: EVALUATE RESULTS
# ...
#
# BUSINESS SUCCESS CRITERIA
# ...
#
# [PASS] Build a working model to predict traffic volume
#
# Target
# ------
# A complete regression model that can generate reliable traffic volume predictions
#
# Achieved
# --------
# Achieved. Multiple regression models were trained and compared, and the Tuned Random Forest
# Regressor was selected as the final model.
#
# [PASS] Achieve strong predictive performance for practical forecasting use
#
# Target
# ------
# Model should explain most of the variation in traffic volume and generalise well to unseen data
#
# Achieved
# --------
# Achieved. The Tuned Random Forest Regressor achieved a test R² of 0.966, meaning it explains about
# 96.6% of the variation in traffic volume on unseen data.
#
# [PASS] Improve traffic forecasting compared with simpler baseline models
#
# Target
# ------
# Final model should outperform simpler linear models and other alternatives
#
# Achieved
# --------
# ...

# %% [markdown]
# ---
# ### Task 2: Review Process
#
# Conduct a thorough review of the entire CRISP-DM process executed so far. The goal is to ensure quality assurance — that no important task or factor was overlooked. Consider:
#
# - **Completeness Check:** Were all relevant data sources considered? Were the data preparation steps sufficient?
# - **Methodology Review:** Were appropriate techniques used at each stage? Were there alternatives worth exploring?
# - **Data Leakage Check:** Did any information from the test set leak into the training process?
# - **Bias and Fairness:** Could the model introduce or amplify any biases? Is the model fair across different subgroups?
# - **Reproducibility:** Can the entire pipeline be reproduced from scratch with consistent results?
#
# **Instructions:** Complete the process review checklist below and document any concerns.

# %%
# Task 2: Review the full CRISP-DM process

process_review = {
    "checklist": [
        {
            "item": "Business objective was clearly defined",
            "status": "Yes",
            "notes": "The project goal was clearly established in Phase 1: to build a model that predicts traffic volume accurately enough to support traffic forecasting and related decision-making."
        },
        {
            "item": "Relevant data was selected",
            "status": "Yes",
            "notes": "The Metro Interstate Traffic Volume dataset included traffic volume, date/time information, weather-related variables, and holiday information, all of which are relevant to the forecasting problem."
        },
        {
            "item": "Data understanding was carried out properly",
            "status": "Yes",
            "notes": "The dataset was explored through summary statistics, structure checks, missing value checks, duplicate checks, distribution analysis, and visual exploration."
        },
        {
            "item": "Data preparation was appropriate and documented",
            "status": "Yes",
            "notes": "The workflow included cleaning, handling missing values, encoding categorical features, converting date columns, and constructing useful derived features for modelling."
        },
        {
            "item": "Feature engineering improved the dataset",
            "status": "Yes",
            "notes": "Additional time-based features were created from the date column, helping the models capture daily, monthly, and seasonal traffic patterns more effectively."
        },
        {
            "item": "Train/test split was used correctly",
            "status": "Yes",
            "notes": "The data was separated into training and testing sets before final evaluation, allowing model performance to be measured on unseen data."
        },
        {
            "item": "Model comparison was sufficient",
            "status": "Yes",
            "notes": "Several models were trained and compared, including Linear Regression, Ridge Regression, Gradient Boosting, Random Forest, and Tuned Random Forest."
        },
        {
            "item": "Hyperparameter tuning was performed",
            "status": "Yes",
            "notes": "Grid search was used to tune the Random Forest model, leading to the best final-performing model."
        },
        {
            "item": "Risk of data leakage was minimised",
            "status": "Yes",
            "notes": "Model evaluation was performed on a held-out test set, and tuning was based on training data with cross-validation rather than directly optimising on the test set."
        },
        {
            "item": "Results are reproducible",
            "status": "Mostly",
            "notes": "The workflow is reproducible because the notebook documents the main steps clearly. Reproducibility would be strengthened further by finalising reusable functions in the src folder and using a full pipeline."
        }
    ],
    
    "strengths": [
        "The project followed the CRISP-DM structure consistently across phases.",
        "The data preparation process improved data quality and modelling readiness.",
        "The modelling phase included multiple algorithms rather than relying on only one approach.",
        "Hyperparameter tuning strengthened the final model selection.",
        "The final model achieved very strong performance on unseen test data."
    ],
    
    "areas_for_improvement": [
        "A full reusable pipeline script structure in src should be finalised to improve reproducibility and deployment readiness.",
        "Further validation on future or external data would strengthen confidence in real-world performance.",
        "Feature importance analysis or interpretability analysis could be expanded.",
        "Time-based validation could be considered in future work because traffic data is naturally time dependent.",
        "Deployment monitoring and retraining strategy would still be needed in a real implementation."
    ],
    
    "overall_quality": "The overall project process was strong and well-structured. The work followed the CRISP-DM methodology appropriately, included meaningful data preparation and model comparison, and produced a reliable final model. Only a few improvement areas remain before full deployment readiness."
}

# %%
# Display process review clearly

def print_block(title, content, width=100):
    print(f"\n{title}")
    print("-" * len(title))
    print(fill(str(content), width=width))

print("PHASE 5 - TASK 2: REVIEW PROCESS")
print("=" * 36)

print("\nPROCESS REVIEW CHECKLIST")
print("=" * 24)

for item in process_review["checklist"]:
    print(f"\n[{item['status']}] {item['item']}")
    print_block("Notes", item["notes"])

print("\nPROJECT STRENGTHS")
print("=" * 17)
for point in process_review["strengths"]:
    print(f"- {fill(point, width=100)}")

print("\nAREAS FOR IMPROVEMENT")
print("=" * 21)
for point in process_review["areas_for_improvement"]:
    print(f"- {fill(point, width=100)}")

print_block("Overall Quality", process_review["overall_quality"])
# Out:
# PHASE 5 - TASK 2: REVIEW PROCESS
# ...
#
# PROCESS REVIEW CHECKLIST
# ...
#
# [Yes] Business objective was clearly defined
#
# Notes
# -----
# The project goal was clearly established in Phase 1: to build a model that predicts traffic volume
# accurately enough to support traffic forecasting and related decision-making.
#
# [Yes] Relevant data was selected
#
# Notes
# -----
# The Metro Interstate Traffic Volume dataset included traffic volume, date/time information, weather-
# related variables, and holiday information, all of which are relevant to the forecasting problem.
#
# [Yes] Data understanding was carried out properly
#
# Notes
# -----
# The dataset was explored through summary statistics, structure checks, missing value checks,
# duplicate checks, distribution analysis, and visual exploration.
#
# [Yes] Data preparation was appropriate and documented
#
# Notes
# -----
# The workflow included cleaning, handling missing values, encoding categorical features, converting
# ...

# %% [markdown]
# ---
# ### Task 3: Determine Next Steps
#
# Based on the evaluation results and process review, decide on the next course of action. The three main options are:
#
# 1. **Proceed to Deployment:** The model meets all criteria and is ready for deployment.
# 2. **Iterate:** Go back to a previous phase (e.g., Data Preparation or Modelling) to improve the model before deployment.
# 3. **Terminate:** The project is not viable in its current form and should be re-scoped or abandoned.
#
# **Instructions:** Document your decision and provide a clear rationale.

# %%
# Task 3: Determine next steps

next_steps = {
    "decision": "Proceed to Deployment",
    
    "rationale": (
        "The project should proceed to deployment because the final selected model "
        "(Tuned Random Forest Regressor) achieved excellent results and clearly outperformed "
        "the other candidate models. Its test R² score of 0.965982 is far above the original "
        "minimum success target, and the tuning process also showed strong cross-validation performance. "
        "The overall CRISP-DM process was completed properly, and no major issue was identified that would "
        "justify terminating the project or returning to earlier phases before moving forward."
    ),
    
    "selected_model": "Tuned Random Forest Regressor",
    
    "why_this_model": [
        "It achieved the strongest overall predictive performance.",
        "It outperformed the untuned Random Forest by a small but meaningful margin.",
        "It performed substantially better than Linear Regression and Ridge Regression.",
        "It generalised well to unseen test data."
    ],
    
    "deployment_readiness": [
        "The model is ready for a demonstration or academic deployment stage.",
        "The notebook workflow is complete enough to support the final project submission.",
        "A reusable src pipeline would further improve real deployment readiness."
    ],
    
    "recommended_follow_up": [
        "Package preprocessing and prediction steps into reusable src functions.",
        "Save the final trained model for reuse.",
        "Document model inputs, outputs, and limitations clearly in Phase 6.",
        "Consider monitoring and retraining if the model were used in a real-world setting."
    ]
}

# %%
# Display next steps decision clearly

def print_block(title, content, width=100):
    print(f"\n{title}")
    print("-" * len(title))
    print(fill(str(content), width=width))

print("PHASE 5 - TASK 3: DETERMINE NEXT STEPS")
print("=" * 41)

print_block("Decision", next_steps["decision"])
print_block("Rationale", next_steps["rationale"])
print_block("Selected Model", next_steps["selected_model"])

print("\nWHY THIS MODEL WAS SELECTED")
print("=" * 27)
for point in next_steps["why_this_model"]:
    print(f"- {fill(point, width=100)}")

print("\nDEPLOYMENT READINESS")
print("=" * 20)
for point in next_steps["deployment_readiness"]:
    print(f"- {fill(point, width=100)}")

print("\nRECOMMENDED FOLLOW-UP ACTIONS")
print("=" * 29)
for point in next_steps["recommended_follow_up"]:
    print(f"- {fill(point, width=100)}")
# Out:
# PHASE 5 - TASK 3: DETERMINE NEXT STEPS
# ...
#
# Decision
# --------
# Proceed to Deployment
#
# Rationale
# ---------
# The project should proceed to deployment because the final selected model (Tuned Random Forest
# Regressor) achieved excellent results and clearly outperformed the other candidate models. Its test
# R² score of 0.965982 is far above the original minimum success target, and the tuning process also
# showed strong cross-validation performance. The overall CRISP-DM process was completed properly, and
# no major issue was identified that would justify terminating the project or returning to earlier
# phases before moving forward.
#
# Selected Model
# --------------
# Tuned Random Forest Regressor
#
# WHY THIS MODEL WAS SELECTED
# ...
# - It achieved the strongest overall predictive performance.
# - It outperformed the untuned Random Forest by a small but meaningful margin.
# - It performed substantially better than Linear Regression and Ridge Regression.
# ...
